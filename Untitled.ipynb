# %%
import numpy as np

# %%
import os

# %%
from PIL import Image

# %%
for root, dirs, files in os.walk('Data/traffic_signs/'):
    for file in files:
        im = Image.open(root + '/' + file)
        print(im.size)
# Out:
# (30, 30)
# (27, 26)
# (65, 65)
# (37, 36)
# (51, 61)
# (56, 55)
# (77, 80)
# (40, 41)
# (32, 32)
# (47, 50)
# (29, 29)
# (30, 30)
# (36, 40)
# (44, 51)
# (22, 21)
# (40, 41)
# (28, 28)
# (26, 26)
# (27, 27)
# (66, 67)
# (60, 59)
# (31, 30)
# (18, 20)
# (35, 35)
# (20, 20)
# (51, 51)
# (61, 62)
# (21, 22)
# (89, 92)
# (61, 62)
# (42, 42)
# (38, 37)
# (43, 41)
# (55, 66)
# (69, 67)
# (69, 67)
# (62, 62)
# (33, 34)
# (29, 29)
# (38, 38)
# (65, 64)
# (29, 29)
# (21, 20)
# (33, 33)
# (47, 47)
# (46, 46)
# (23, 23)
# (34, 35)
# (26, 26)
# (25, 25)
# (99, 96)
# (19, 21)
# (47, 46)
# (40, 41)
# (57, 57)
# (52, 53)
# (35, 35)
# (54, 55)
# (27, 27)
# (29, 30)
# (30, 31)
# (42, 42)
# (37, 36)
# (34, 32)
# (45, 45)
# (46, 47)
# (32, 32)
# (25, 25)
# (33, 33)
# (47, 47)
# (33, 33)
# (25, 25)
# (74, 70)
# (65, 64)
# (26, 26)
# (26, 27)
# (24, 24)
# (40, 40)
# (47, 47)
# (58, 62)
# (73, 73)
# (33, 33)
# (56, 56)
# (50, 53)
# (64, 65)
# (27, 27)
# (78, 76)
# (44, 43)
# (56, 56)
# (56, 56)
# ...
